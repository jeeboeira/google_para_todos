# %%
import os
import re

# Caminho da pasta
folder = "/home/jesse/00-REPOS/01-PERSONAL/00-EXTENSAO_III/google_para_todos/images/agenda/configuracoes"


def natural_key(text):
    """Divide o texto em partes numéricas e não numéricas para ordenar corretamente."""
    return [int(s) if s.isdigit() else s.lower() for s in re.split(r'(\d+)', text)]

# Lista todos os arquivos (ignorando subpastas)
files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
files = [f for f in files if f.lower().endswith(".png")]

# Ordena naturalmente: Imagem 1, Imagem 2, ..., Imagem 10
files.sort(key=natural_key)

# Percorre e renomeia
for i, filename in enumerate(files, start=1):
    if not filename.lower().endswith(".png"):
        continue
    new_name = f"Imagem{i}.png"
    old_path = os.path.join(folder, filename)
    new_path = os.path.join(folder, new_name)
    os.rename(old_path, new_path)
    print(f"{filename} → {new_name}")

print("Renomeação concluída.")
# Out:
# Imagem 1 - Configurações agenda.png → Imagem1.png
# Imagem 2 - Configurações agenda.png → Imagem2.png
# Imagem 3 - Configurações agenda.png → Imagem3.png
# Imagem 4 - Configurações agenda.png → Imagem4.png
# Imagem 5 - Configurações agenda.png → Imagem5.png
# Imagem 6 - Configurações agenda.png → Imagem6.png
# Imagem 7 - Configurações agenda.png → Imagem7.png
# Imagem 8 - Configurações agenda.png → Imagem8.png
# Imagem 9 - Configurações agenda.png → Imagem9.png
# Imagem 10 - Configurações agenda.png → Imagem10.png
# Imagem 11 - Configurações agenda.png → Imagem11.png
# Imagem 12 - Configurações agenda.png → Imagem12.png
# Imagem 13 - Configurações agenda.png → Imagem13.png
# Imagem 14 - Configurações agenda.png → Imagem14.png
# Imagem 15 - Configurações agenda.png → Imagem15.png
# Renomeação concluída.
