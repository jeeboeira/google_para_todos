# %%
import os
import re

# Caminho da pasta
folder = "/home/jesse/00-REPOS/01-PERSONAL/google_para_todos/images/agenda/gerenciamento_entradas_no_calendario_pt_II"


def natural_key(text):
    """Divide o texto em partes numéricas e não numéricas para ordenar corretamente."""
    return [int(s) if s.isdigit() else s.lower() for s in re.split(r'(\d+)', text)]

# Lista todos os arquivos (ignorando subpastas)
files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
files = [f for f in files if f.lower().endswith(".png")]

# Ordena naturalmente: Imagem 1, Imagem 2, ..., Imagem 10
files.sort(key=natural_key)

# Percorre e renomeia
for i, filename in enumerate(files, start=0):
    if not filename.lower().endswith(".png"):
        continue
    new_name = f"Imagem{i}.png"
    old_path = os.path.join(folder, filename)
    new_path = os.path.join(folder, new_name)
    os.rename(old_path, new_path)
    print(f"{filename} → {new_name}")

print("Renomeação concluída.")
# Out:
# Imagem1.png → Imagem0.png
# Imagem2.png → Imagem1.png
# Imagem3.png → Imagem2.png
# Imagem4.png → Imagem3.png
# Imagem5.png → Imagem4.png
# Imagem6.png → Imagem5.png
# Imagem7.png → Imagem6.png
# Imagem8.png → Imagem7.png
# Imagem9.png → Imagem8.png
# Imagem10.png → Imagem9.png
# Imagem11.png → Imagem10.png
# Imagem12.png → Imagem11.png
# Imagem13.png → Imagem12.png
# Imagem14.png → Imagem13.png
# Imagem15.png → Imagem14.png
# Imagem16.png → Imagem15.png
# Imagem17.png → Imagem16.png
# Imagem18.png → Imagem17.png
# Imagem19.png → Imagem18.png
# Imagem20.png → Imagem19.png
# Imagem21.png → Imagem20.png
# Renomeação concluída.
